# %% [markdown]
# ✅ TASK 01: Distribution Visualization
#
#     🔹 Objective:
#
#         Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable.
#
#     🔹 I’ll Do:
#
#         o)Use a simple dataset (Titanic or India population).
#
#         o)Choose one variable: e.g., Age or Gender.
#
#         o)Visualize it using matplotlib or seaborn.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact

sns.set(style="whitegrid")

# %%
df = pd.read_csv("Task-1(skillcraft).csv")
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                            NaN          NaN                NaN
# 1                          Aruba          ABW  Population, total
# 2    Africa Eastern and Southern          AFE  Population, total
# 3                    Afghanistan          AFG  Population, total
# 4     Africa Western and Central          AFW  Population, total
# ..                           ...          ...                ...
# 262                       Kosovo          XKX  Population, total
# 263                  Yemen, Rep.          YEM  Population, total
# 264                 South Africa          ZAF  Population, total
# 265                       Zambia          ZMB  Population, total
# 266                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0              NaN          NaN          NaN          NaN          NaN
# ...

# %%
print("Available countries (sample 10):", df['Country Name'].unique()[:10])
print("\nAvailable indicators (sample 10):", df['Indicator Name'].unique()[:10])
# Out:
# Available countries (sample 10): [nan 'Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates']
#
# Available indicators (sample 10): [nan 'Population, total']

# %%
df = pd.read_csv("Task-1(skillcraft).csv")
year_columns = [col for col in df.columns if col.isdigit()]

# %%
df = df.dropna(subset=['Country Name', 'Indicator Name'])
df = df[df['Country Name'].apply(lambda x: isinstance(x, str))]
df = df[df['Indicator Name'].apply(lambda x: isinstance(x, str))]

# %%
country_options = sorted(df['Country Name'].unique())
indicator_options = sorted(df['Indicator Name'].unique())

# %%
def plot_bar(country, indicator):
    data = df[(df['Country Name'] == country) & (df['Indicator Name'] == indicator)]

    if data.empty:
        print("No data available for this combination.")
        return

    melted = data.melt(id_vars=['Country Name', 'Indicator Name'],value_vars=year_columns,var_name='Year', value_name='Value')

    melted['Year'] = pd.to_numeric(melted['Year'], errors='coerce')
    melted.dropna(subset=['Value'], inplace=True)

    plt.figure(figsize=(12,6))
    plt.bar(melted['Year'], melted['Value'], color='#4682B4')
    plt.title(f"{indicator} in {country}", fontsize=14)
    plt.xlabel("Years")
    plt.ylabel("Population in Billions")
    plt.xticks(melted['Year'], rotation=90, fontsize=8)
    plt.grid(axis='y', linestyle='--', alpha=0.4)
    plt.tight_layout()
    plt.show()


interact(plot_bar, country=country_options, indicator=indicator_options)
# Out:
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Africa Eastern and Southern', '…
# <function __main__.plot_bar(country, indicator)>

# %% [markdown]
#     Note: This data is sourced from the **World Bank** database.
#         I do not claim ownership of this dataset.
#         For further queries or exploration, please refer to the official dataset from the [World Bank Data Portal]
#         https://data.worldbank.org/indicator/SP.POP.TOTL?end=2024&start=2022.
